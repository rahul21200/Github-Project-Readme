# %%
# %pip install FER
from fer import FER
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Collecting FER
#   Using cached fer-22.4.0-py3-none-any.whl (812 kB)
# Requirement already satisfied: mtcnn>=0.1.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from FER) (0.1.1)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: tqdm in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from FER) (4.62.3)
# Requirement already satisfied: keras>=2.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from FER) (2.7.0)
# Requirement already satisfied: requests in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from FER) (2.26.0)
# Requirement already satisfied: opencv-contrib-python in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from FER) (4.5.5.64)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from FER) (3.4.3)
# Requirement already satisfied: opencv-python>=4.1.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from mtcnn>=0.1.1->FER) (4.5.5.62)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->FER) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->FER) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->FER) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->FER) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->FER) (1.19.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->FER) (9.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->FER) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->FER) (2.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->FER) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from requests->FER) (3.2)
# Requirement already satisfied: colorama in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from tqdm->FER) (0.4.4)
# Requirement already satisfied: six in c:\users\user\appdata\local\programs\python\python39\lib\site-packages (from cycler>=0.10->matplotlib->FER) (1.16.0)
# Installing collected packages: FER
# Successfully installed FER-22.4.0
# WARNING: You are using pip version 22.0.3; however, version 22.3.1 is available.
# You should consider upgrading via the 'c:\Users\USER\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## Face Detecion on a static image
# #### Using FER(open source emotion detection library)

# %%
test_image_one = plt.imread("assets/img1.jpeg")

# %%
# Initiating the constructor 
emo_detector = FER(mtcnn=True)

# %%
# # Capture all the emotions on the image
# Emo_detector = emotion detector function from FER
captured_emotions = emo_detector.detect_emotions(test_image_one)

# %%
# Print all captured emotions with the image
print(captured_emotions)
# Out:
# [{'box': [66, 7, 160, 219], 'emotions': {'angry': 0.0, 'disgust': 0.0, 'fear': 0.0, 'happy': 0.99, 'sad': 0.0, 'surprise': 0.0, 'neutral': 0.01}}]

# %%
plt.imshow(test_image_one)

# %%
# Use the top Emotion() function to call for the dominant emotion in the image
dominant_emotion, emotion_score = emo_detector.top_emotion(test_image_one)

# %%
print(dominant_emotion, emotion_score)
# Out:
# happy 0.99
